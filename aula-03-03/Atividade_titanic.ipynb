# %% [markdown]
# # Atividade
#
# - Explorar os conjuntos de dados `iris` e `titanic` ambos dentro da biblioteca `seaborn`
#
# - Para cada conjunto de dados criar:
#     - Uma visualização apropriada para cada variável.
#     - Cinco visualizações que mostrem a relação entre duas variáveis nos eixos e utilizem mais uma variável categorórica para a cor ou o estilo.
#     - Três visualizações que utilizem fatoração de uma variável categórica para separar os graficos, usando `facets`.
#     - Dois modelos de `pairplot` para apenas o dataset `iris`.
#     - Um gráfico interativo utilizando `plotly`.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Conjunto de dados IRIS

# %%
df = sns.load_dataset('iris')
with pd.option_context('display.max_rows',10):
    display(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Descrição textual dos dados
#
# `sepal_length` representa o comprimento da pétala
#
# `sepal_width` representa a largura da pétala
#
# `petal_length` representa o comprimento da sépala
#
# `petal_width` representa a largura da sépala
#
# `species` representa as espécie/raça da planta

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ## Species
# Podem possuir os valores `setosa`, `versicolor`, `virginica`.

# %% [markdown]
# ### Descrição dos tipos de dados de cada coluna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ### Descrição de Variáveis Numéricas (contínuas e discretas) por Estatísticas Descritivas.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Relação entre uma variável categórica e uma contínua
#
# - Vizualização `sepal_length` em relação às espécies
# - Vizualização `sepal_width` em relação às espécies
# - Vizualização `petal_length` em relação às espécies
# - Vizualização `petal_width` em relação às espécies

# %%
fig, ax = plt.subplots(1,4, figsize=(16,6))
sns.catplot(x="species", y="sepal_length", data=df, ax=ax[0]);
sns.catplot(x="species", y="sepal_width" , data=df, ax=ax[1]);
sns.catplot(x="species", y="petal_length", data=df, ax=ax[2]);
sns.catplot(x="species", y="petal_width" , data=df, ax=ax[3]);

# %%
fig, ax = plt.subplots(1,4, figsize=(16,6))
sns.catplot(x="species", y="sepal_length",ax=ax[0], kind="box",data=df);
sns.catplot(x="species", y="sepal_width", ax=ax[1], kind="box", data=df);
sns.catplot(x="species", y="petal_length",ax=ax[2], kind="box", data=df);
sns.catplot(x="species", y="petal_width", ax=ax[3], kind="box", data=df);

# %% [markdown]
# ## Gráficos de Densidade

# %%
sns.kdeplot(df.query('species == "setosa"').sepal_length, shade = True, label = 'species = setosa')
sns.kdeplot(df.query('species == "versicolor"').sepal_length, shade = True, label = 'species = versicolor')
sns.kdeplot(df.query('species == "virginica"').sepal_length, shade = True, label = 'species = virginica')

# %%
sns.kdeplot(df.query('species == "setosa"').sepal_width, shade = True, label = 'species = setosa')
sns.kdeplot(df.query('species == "versicolor"').sepal_width, shade = True, label = 'species = versicolor')
sns.kdeplot(df.query('species == "virginica"').sepal_width, shade = True, label = 'species = virginica')

# %%
sns.kdeplot(df.query('species == "setosa"').petal_width, shade = True, label = 'species = setosa')
sns.kdeplot(df.query('species == "versicolor"').petal_width, shade = True, label = 'species = versicolor')
sns.kdeplot(df.query('species == "virginica"').petal_width, shade = True, label = 'species = virginica')

# %%
sns.kdeplot(df.query('species == "setosa"').petal_length, shade = True, label = 'species = setosa')
sns.kdeplot(df.query('species == "versicolor"').petal_length, shade = True, label = 'species = versicolor')
sns.kdeplot(df.query('species == "virginica"').petal_length, shade = True, label = 'species = virginica')

# %% [markdown]
# ## Correlação entre variáveis

# %%
sns.pairplot(df, kind="reg");

# %%
sns.pairplot(df, hue="species")

# %%
sns.pairplot(df, hue="species", kind="reg")
